# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/DataAnalysis
# Out:
# /content/drive/MyDrive/DataAnalysis

# %%
# !git clone https://SONG-3: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@github.com/SONG-3/DataAnalysis.git
# Out:
# Cloning into 'DataAnalysis'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
cd DataAnalysis
# Out:
# /content/drive/MyDrive/DataAnalysis/DataAnalysis

# %%
# !git config --global user.email rudrms3565@naver.com
# !git config --global user.name SONG-3

# %%
# !git add DataAnalysis.ipynb
# Out:
# fatal: pathspec 'DataAnalysis.ipynb' did not match any files
